# %%
# Standard imports 

from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f2965db7-23e1-4d35-a542-adce39700d51">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure, output_file, show

# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# output to static HTML file
output_notebook()

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Temp.", line_width=2)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8d9bbeaf-6605-416c-9bd5-d681ed7babf8">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="3dede25a-fb63-4bca-92d7-9446f6e3b700"></div>
# </div>

# %%
import pandas as pd
import datetime

def date_parser_function(dateAsString):
    return datetime.datetime.strptime(dateAsString,"%m/%d/%Y")

df = pd.read_csv("~/Programming/Python/BT/tests/TimeSeries",
                index_col="Date",
                parse_dates=["Date"],
                date_parser=date_parser_function,
                sep="\t")

# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="630d5d91-c667-4cea-ad85-b9e33ea17ef7">Loading BokehJS ...</span>
#     </div>

# %%
x = np.linspace(0, 1, 100)
y2 = df['H2']
y3 = df['H3']
y4 = df['H4']

# %%
p = figure(title="my own interactive graph", plot_height=300, plot_width=600, y_range=(-5,5))
r2 = p.line(x, y2, color="#2222aa", line_width=3, visible=True)
r3 = p.line(x, y3, color="#2222aa", line_width=3, visible=False)
r4 = p.line(x, y4, color="#2222aa", line_width=3, visible=False)

# %%
def update(**kwargs):
    for k,v in kwargs.items():
        if k == "2":
            r2.visible = v
        if k == "3":
            r3.visible = v
        if k == "4":
            r4.visible = v
    push_notebook()

# %%
show(p, notebook_handle=True)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="09564ce7-ba08-48c6-b9e0-0aa54c158c62"></div>
# </div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[8]</strong>&gt;</code></p>

# %%
interact(update, **{str(x+2) : False for x in range(3)})
# Out:
# A Jupyter Widget
# <function __main__.update>
